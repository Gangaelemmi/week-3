# %% [markdown]
# # Assignment-3

# %% [markdown]
# # a)read text file

# %%
import pandas as pd
import numpy as np
cols=['symboling','normalized-losses','make','fuel-type','aspiration','num-of-door']
data=pd.read_csv("Automobile_data.csv")
print(data.head().shape)
data.head()
# Out:
# (5, 26)
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# # b)identify missing values evaluate missing values .deal with missing values and cirrect data format

# %%
data=data.replace("?",np.NaN)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
#evaluating the missing values
data.isnull().any().any()
# Out:
# True

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#compute the mean of 'normalized_losses'
avg_norm_loss=data['normalized-losses'].astype("float").mean()
avg_norm_loss
# Out:
# 122.0

# %%
# replace missing values by mean
data['normalized-losses'].replace(np.NaN,avg_norm_loss,inplace=True)
data['normalized-losses']
# Out:
# 0      122
# 1      122
# 2      122
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object

# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.5

# %%
avg_bore=data['bore'].astype("float").mean()
avg_bore
# Out:
# 5.645268292682923

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# min    1488.000000    61.000000           7.000000   13.000000    16.000000
# 25%    2145.000000    97.000000           8.600000   19.000000    25.000000
# 50%    2414.000000   120.000000           9.000000   24.000000    30.000000
# 75%    2935.000000   141.000000           9.400000   30.000000    34.000000
# max    4066.000000   326.000000          23.000000   49.000000    54.000000

# %%
#replace missing values by mean
data['bore'].replace(np.NaN,avg_norm_loss,inplace=True)
data('bore')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-fd2d0c273921> in <module>
#       1 #replace missing values by mean
#       2 data['bore'].replace(np.NaN,avg_norm_loss,inplace=True)
# ----> 3 data('bore')
#
# TypeError: 'DataFrame' object is not callable

# %%
#compute mean of 'stroke'
avg_stroke = data['stroke'].astype("float").mean(axis=0)
avg_stroke
# Out:
# 5.572390243902446

# %%
data['stroke'].replace(np.NaN,avg_norm_loss,inplace=True)
data['stroke']
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3       3.4
# 4       3.4
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203     3.4
# 204    3.15
# Name: stroke, Length: 205, dtype: object

# %%
#get the tottal number of missing values now
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
#datatype of'bore'
data['bore'].dtype
# Out:
# dtype('O')

# %%
#find average value of 'horsepower'
avg_horsepower=data['horsepower'].astype("float").mean(axis=0)
avg_horsepower
# Out:
# 104.25615763546799

# %%
#replace all the missing values by average value
data['horsepower'].replace(np.NaN,avg_norm_loss,inplace=True)
data['horsepower']
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: object

# %%
#find average value of 'peak-rpm'
avg_peakrpm=data['peak-rpm'].astype("float").mean(axis=0)
avg_peakrpm
# Out:
# 5125.369458128079

# %%
#replace all the missing values by average value
data['peak-rpm'].replace(np.NaN,avg_norm_loss,inplace=True)
data['peak-rpm']
# Out:
# 0      5000
# 1      5000
# 2      5000
# 3      5500
# 4      5500
#        ...
# 200    5400
# 201    5300
# 202    5500
# 203    4800
# 204    5400
# Name: peak-rpm, Length: 205, dtype: object

# %%
#replaceing the missing valuees present in'num-of-doors'
data['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
data['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
data['num-of-doors'].replace(np.NaN,'four',inplace=True)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          3               122  alfa-romero       gas        std          two
# 2          1               122  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
#evaluating the missing values of 'price' attribute
before_rows=data.shape[0]
data.dropna(subset=['price'],axis=0,inplace=True)
after_rows=data.shape[0]
print("Number of dropped rows:{}".format(before_rows-after_rows))
#reset index values
data.reset_index(drop=True,inplace=True)
# Out:
# Number of dropped rows:4

# %%
#getting the tottal number of rows and columns of the dataset
data.shape
# Out:
# (201, 26)

# %%
#listing the datatypeof each attribute
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#convert to datatypes to proper format
data[['bore','stroke',]]=data[['bore','stroke']].astype("float")
data[['normalized-losses']]=data[['normalized-losses']].astype("int")
data[['price']]=data[['price']].astype("float")
data[['peak-rpm']]=data[['peak-rpm']].astype("float")
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak-rpm city-mpg  highway-mpg    price
# 0    5000.0       21           27  13495.0
# 1    5000.0       21           27  16500.0
# 2    5000.0       19           26  16500.0
# 3    5500.0       24           30  13950.0
# 4    5500.0       18           22  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # c)data standardizaton

# %%
#transform mpg to l\100km by mathematicaln operation
data['highway-mpg']=235/data['highway-mpg']
#rename tha column name
data.rename(columns={'highway-mpg':'higway-L/100km'},inplace=True)
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak-rpm city-mpg  higway-L/100km    price
# 0    5000.0       21        8.703704  13495.0
# 1    5000.0       21        8.703704  16500.0
# 2    5000.0       19        9.038462  16500.0
# 3    5500.0       24        7.833333  13950.0
# 4    5500.0       18       10.681818  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # d)data normalization(centring/scaling)

# %%
#normalization of the data
data['length']=data['length']/data['length'].max()
data['width']=data['width']/data['width'].max()
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak-rpm city-mpg  higway-L/100km    price
# 0    5000.0       21        8.703704  13495.0
# 1    5000.0       21        8.703704  16500.0
# 2    5000.0       19        9.038462  16500.0
# 3    5500.0       24        7.833333  13950.0
# 4    5500.0       18       10.681818  17450.0
#
# [5 rows x 26 columns]

# %%
#normalization of 'height'
data['height']=data['height']/data['height'].max()
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak-rpm city-mpg  higway-L/100km    price
# 0    5000.0       21        8.703704  13495.0
# 1    5000.0       21        8.703704  16500.0
# 2    5000.0       19        9.038462  16500.0
# 3    5500.0       24        7.833333  13950.0
# 4    5500.0       18       10.681818  17450.0
#
# [5 rows x 26 columns]

# %%
#e)BINNING

# %%
#convert data to correct format
data['horsepower']=data['horsepower'].astype(int,copy=True)
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak-rpm city-mpg  higway-L/100km    price
# 0    5000.0       21        8.703704  13495.0
# 1    5000.0       21        8.703704  16500.0
# 2    5000.0       19        9.038462  16500.0
# 3    5500.0       24        7.833333  13950.0
# 4    5500.0       18       10.681818  17450.0
#
# [5 rows x 26 columns]

# %%
#plot the histogram with respect to 'horsepower'
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(data['horsepower'])
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
#binning
bins=np.linspace(min(data['horsepower']),max(data['horsepower']),4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names=['low','medium','high']
data['horsepower-binned']=pd.cut(data['horsepower'],bins,labels=group_names,include_lowest=True)
data[['horsepower-binned','horsepower-binned']].head(20)
# Out:
#    horsepower-binned horsepower-binned
# 0                low               low
# 1                low               low
# 2             medium            medium
# 3                low               low
# 4                low               low
# 5                low               low
# 6                low               low
# 7                low               low
# 8             medium            medium
# 9                low               low
# 10               low               low
# 11            medium            medium
# 12            medium            medium
# 13            medium            medium
# 14            medium            medium
# 15            medium            medium
# 16            medium            medium
# 17               low               low
# 18               low               low
# 19               low               low

# %%
#total number of elements based on group_name
data['horsepower-binned'].value_counts()
# Out:
# low       151
# medium     45
# high        5
# Name: horsepower-binned, dtype: int64

# %%
#plotting the baragraph
# %matplotlib inline
import matplotlib.pyplot as plt
plt.bar(group_names,data['horsepower-binned'].value_counts())
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
#bins visualization
# %matplotlib inline
import matplotlib.pyplot as plt
a=(0,1,2)
plt.hist(data['horsepower'],bins=3)
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower binns")
plt.show()

# %% [markdown]
# # f) indicator variable

# %%
#getting the indicator variable
dummy_variable_1=pd.get_dummies(data['fuel-type'])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
#rename the columns
dummy_variable_1.rename(columns={'fuel-type-gas':'gas','fuel-type=diesel':'diesel'})
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
#merge dataframe and dummy variables
data=pd.concat([data,dummy_variable_1],axis=1)

#drop original column 'fuel-type'
data.drop('fuel-type',axis=1,inplace=True)
data.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    stroke  compression-ratio  horsepower peak-rpm city-mpg  higway-L/100km  \
# 0    2.68                9.0         111   5000.0       21        8.703704
# 1    2.68                9.0         111   5000.0       21        8.703704
# 2    3.47                9.0         154   5000.0       19        9.038462
# 3    3.40               10.0         102   5500.0       24        7.833333
# 4    3.40                8.0         115   5500.0       18       10.681818
#
#      price  horsepower-binned  diesel  gas
# 0  13495.0                low       0    1
# 1  16500.0                low       0    1
# 2  16500.0             medium       0    1
# 3  13950.0                low       0    1
# 4  17450.0                low       0    1
#
# [5 rows x 28 columns]

# %%
#seconnd dummy variable
dummy_variable_2=pd.get_dummies(data['aspiration'])
dummy_variable_2.rename(columns={'std':'aspiration-std','turbo':'aspiration-turbo'})
dummy_variable_2.head()
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
#merge dataframe and dummy variables
data=pd.concat([data,dummy_variable_2],axis=1)

#drop original column 'fuel-type'
data.drop('aspiration',axis=1,inplace=True)
data.head()
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          3                122  alfa-romero          two  convertible
# 2          1                122  alfa-romero          two    hatchback
# 3          2                164         audi         four        sedan
# 4          2                164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  \
# 0          rwd           front        88.6  0.811148  0.890278  ...
# 1          rwd           front        88.6  0.811148  0.890278  ...
# 2          rwd           front        94.5  0.822681  0.909722  ...
# 3          fwd           front        99.8  0.848630  0.919444  ...
# 4          4wd           front        99.4  0.848630  0.922222  ...
#
#    horsepower  peak-rpm city-mpg higway-L/100km    price horsepower-binned  \
# 0         111    5000.0       21       8.703704  13495.0               low
# 1         111    5000.0       21       8.703704  16500.0               low
# 2         154    5000.0       19       9.038462  16500.0            medium
# 3         102    5500.0       24       7.833333  13950.0               low
# 4         115    5500.0       18      10.681818  17450.0               low
#
#    diesel  gas  std  turbo
# 0       0    1    1      0
# 1       0    1    1      0
# 2       0    1    1      0
# 3       0    1    1      0
# 4       0    1    1      0
#
# [5 rows x 29 columns]

# %%
#print overallstatistical of the dataset
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean     0.899108  2555.666667   126.875622    5.692289    5.619950
# std      0.040933   517.296727    41.546834   16.616706   16.627881
# min      0.799331  1488.000000    61.000000    2.540000    2.070000
# 25%      0.869565  2169.000000    98.000000    3.150000    3.110000
# 50%      0.904682  2414.000000   120.000000    3.310000    3.290000
# 75%      0.928094  2926.000000   141.000000    3.600000    3.460000
# max      1.000000  4066.000000   326.000000  122.000000  122.000000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  higway-L/100km  \
# count         201.000000  201.000000   201.000000  201.000000      201.000000
# mean           10.164279  103.582090  5067.880597   25.179104        8.044957
# std             4.004965   37.411422   689.686904    6.423220        1.840739
# min             7.000000   48.000000   122.000000   13.000000        4.351852
# 25%             8.600000   70.000000  4800.000000   19.000000        6.911765
# 50%             9.000000   95.000000  5100.000000   24.000000        7.833333
# 75%             9.400000  116.000000  5500.000000   30.000000        9.400000
# max            23.000000  262.000000  6600.000000   49.000000       14.687500
#
#               price      diesel         gas         std       turbo
# count    201.000000  201.000000  201.000000  201.000000  201.000000
# mean   13207.129353    0.099502    0.900498    0.820896    0.179104
# std     7947.066342    0.300083    0.300083    0.384397    0.384397
# min     5118.000000    0.000000    0.000000    0.000000    0.000000
# 25%     7775.000000    0.000000    1.000000    1.000000    0.000000
# 50%    10295.000000    0.000000    1.000000    1.000000    0.000000
# 75%    16500.000000    0.000000    1.000000    1.000000    0.000000
# max    45400.000000    1.000000    1.000000    1.000000    1.000000

# %% [markdown]
# # g)Writing csv file

# %%
#convert to csv file 
data.to_csv("wrangled_data.csv")
data.to_csv
# Out:
# <bound method NDFrame.to_csv of      symboling  normalized-losses         make num-of-doors   body-style  \
# 0            3                122  alfa-romero          two  convertible
# 1            3                122  alfa-romero          two  convertible
# 2            1                122  alfa-romero          two    hatchback
# 3            2                164         audi         four        sedan
# 4            2                164         audi         four        sedan
# ..         ...                ...          ...          ...          ...
# 196         -1                 95        volvo         four        sedan
# 197         -1                 95        volvo         four        sedan
# 198         -1                 95        volvo         four        sedan
# 199         -1                 95        volvo         four        sedan
# 200         -1                 95        volvo         four        sedan
#
#     drive-wheels engine-location  wheel-base    length     width  ...  \
# 0            rwd           front        88.6  0.811148  0.890278  ...
# 1            rwd           front        88.6  0.811148  0.890278  ...
# 2            rwd           front        94.5  0.822681  0.909722  ...
# 3            fwd           front        99.8  0.848630  0.919444  ...
# 4            4wd           front        99.4  0.848630  0.922222  ...
# ..           ...             ...         ...       ...       ...  ...
# 196          rwd           front       109.1  0.907256  0.956944  ...
# 197          rwd           front       109.1  0.907256  0.955556  ...
# 198          rwd           front       109.1  0.907256  0.956944  ...
# 199          rwd           front       109.1  0.907256  0.956944  ...
# 200          rwd           front       109.1  0.907256  0.956944  ...
#
#      horsepower  peak-rpm city-mpg higway-L/100km    price horsepower-binned  \
# 0           111    5000.0       21       8.703704  13495.0               low
# 1           111    5000.0       21       8.703704  16500.0               low
# 2           154    5000.0       19       9.038462  16500.0            medium
# 3           102    5500.0       24       7.833333  13950.0               low
# 4           115    5500.0       18      10.681818  17450.0               low
# ..          ...       ...      ...            ...      ...               ...
# 196         114    5400.0       23       8.392857  16845.0               low
# 197         160    5300.0       19       9.400000  19045.0            medium
# 198         134    5500.0       18      10.217391  21485.0            medium
# 199         106    4800.0       26       8.703704  22470.0               low
# 200         114    5400.0       19       9.400000  22625.0               low
#
#      diesel  gas  std  turbo
# 0         0    1    1      0
# 1         0    1    1      0
# 2         0    1    1      0
# 3         0    1    1      0
# 4         0    1    1      0
# ..      ...  ...  ...    ...
# 196       0    1    1      0
# 197       0    1    0      1
# 198       0    1    1      0
# 199       1    0    0      1
# 200       0    1    0      1
#
# [201 rows x 29 columns]>
